# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

print("numpy:", np.__version__)
print("pandas:", pd.__version__)

# tiny sample
X = np.array([[1],[2],[3],[4]])
y = np.array([2,4,6,8])
model = LinearRegression().fit(X, y)
print("coef:", model.coef_, "intercept:", model.intercept_)

# %%
import pandas as pd

from sklearn.linear_model import LinearRegression

data={
    'Experience':[1,2,3,4,5],
    'Salary':[3000,4000,5000,6000,7000]
}
df=pd.DataFrame(data)

x=df[['Experience']]
y=df[['Salary']]
model=LinearRegression()
model.fit(x,y)

# pass a 2D array (single sample with one feature)
print(model.predict([[10]]))
# Out:
# [[12000.]]
# f:\labtest\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
